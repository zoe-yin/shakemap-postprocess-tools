# %%
import os
import json
import pandas as pd
import numpy as np

input_excel = "/Users/hyin/usgs_mendenhall/ffsimmer/catalog/catalog-development/7.0events_since_2018.xlsx"
output_excel = "/Users/hyin/usgs_mendenhall/ffsimmer/catalog/catalog-development/7.0events_since_2018_strec.xlsx"

# Read spreadsheet
df = pd.read_excel(input_excel)

def extract_values_from_json(eventid):
    """Open JSON file and extract desired fields."""
    json_directory=eventpath=f"/Users/hyin/shakemap_profiles/default/data/{eventid}/"
    json_path = os.path.join(json_directory, f"ffsimmer_pointsource/strec_results.json")
    # print(json_path)
    # Keys to extract
    json_keys = [
        "TectonicRegion",
        "FocalMechanism",
        "ProbabilityActive",
        "ProbabilityStable",
        "ProbabilitySubduction",
        "ProbabilityVolcanic",
        "ProbabilitySubductionCrustal",
        "ProbabilitySubductionInterface",
        "ProbabilitySubductionIntraslab",
        "ProbabilityStableShallow",
        "ProbabilityVolcanicShallow",
        "ProbabilityActiveShallow",
        "ProbabilityActiveDeep"
    ]

    if not os.path.exists(json_path):
        print(f"No JSON file found for {eventid}")
        return {key: np.nan for key in json_keys}

    with open(json_path, "r") as f:
        data = json.load(f)

    # Direct key access (flat JSON)
    extracted = {}
    for key in json_keys:
        value = data.get(key, np.nan)

        # Handle NaN values coming from JSON (if stored as string or null)
        if value is None:
            value = np.nan

        extracted[key] = value

    return extracted


# Extract JSON data for each row
new_columns = df["eventid"].apply(extract_values_from_json)

# Convert list of dicts into dataframe
new_df = pd.DataFrame(list(new_columns))

# Combine with original
df_out = pd.concat([df, new_df], axis=1)

# Write new Excel file
df_out.to_excel(output_excel, index=False)
print(f"New file written to: {output_excel}")
# Out:
# No JSON file found for us1000ggj4
# No JSON file found for us1000gjaz
# No JSON file found for us2000h9e2
# No JSON file found for us2000isc8
# No JSON file found for us600044zz
# No JSON file found for us70007pa9
# No JSON file found for us6000ae4n
# No JSON file found for us7000d20e
# No JSON file found for us6000dher
# No JSON file found for us7000dffl
# No JSON file found for us6000f4ly
# No JSON file found for us6000f53e
# No JSON file found for us6000f65h
# No JSON file found for us6000fr0b
# No JSON file found for us6000h519
# No JSON file found for us7000hcmn
# No JSON file found for us6000iitd
# No JSON file found for us7000i9bw
# No JSON file found for us7000ingi
# No JSON file found for us7000ip8h
# No JSON file found for us7000j36j
# No JSON file found for us7000jkbd
# No JSON file found for us6000k1id
# No JSON file found for us6000k49j
# No JSON file found for us6000kawn
# No JSON file found for us6000kdce
# No JSON file found for us7000k8qh
# No JSON file found for us7000krjx
# No JSON file found for us7000myfa
# No JSON file found for us7000qdyl
# No JSON file found for us6000qvsf
# No JSON file found for us6000r2xq
# No JSON file found for us7000qx2g
# No JSON file found for us6000rgf4
# New file written to: /Users/hyin/usgs_mendenhall/ffsimmer/catalog/catalog-development/7.0events_since_2018_strec.xlsx
